# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing dataset excel file using pandas.
df= pd.read_excel('Flight_Price_dataset_2.xlsx')

# %%
print('No. of Rows :',df.shape[0])
print('No. of Columns :',df.shape[1])
pd.set_option('display.max_columns',None) # This will enable us to see truncated columns
df.head()
# Out:
# No. of Rows : 2955
# No. of Columns : 12
#    Unnamed: 0   Airline          Class Aeroplane              Date  \
# 0           0  Go First  Ecomony Class    G8-334  Sun, 23 Jan 2022
# 1           1  Go First  Ecomony Class    G8-354  Sun, 23 Jan 2022
# 2           2  Go First  Ecomony Class   G8-2501  Sun, 23 Jan 2022
# 3           3  Go First  Ecomony Class    G8-392  Sun, 23 Jan 2022
# 4           4  Go First  Ecomony Class    G8-336  Sun, 23 Jan 2022
#
#   Departure_Time    Arrival_Time     Source Destination     Stops Duration  \
# 0       08:00:00        10:10:00  New Delhi      Mumbai  Non Stop   2h 10m
# 1       22:30:00  00:40\n+ 1 day  New Delhi      Mumbai  Non Stop   2h 10m
# 2       02:00:00        04:15:00  New Delhi      Mumbai  Non Stop   2h 15m
# 3       12:45:00        15:00:00  New Delhi      Mumbai  Non Stop   2h 15m
# 4       14:20:00        16:35:00  New Delhi      Mumbai  Non Stop   2h 15m
#
#    Price
# 0   5954
# 1   5954
# 2   5954
# 3   5954
# 4   5954

# %%
df.drop(columns='Unnamed: 0', inplace =True)

# %%
# lets sort columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Price'], object: ['Airline', 'Class', 'Aeroplane', 'Date', 'Departure_Time', 'Arrival_Time', 'Source', 'Destination', 'Stops', 'Duration']}

# %% [markdown]
# Comment :
#
#     Training dataset contain 2955 rows and 12 columns.
#     Our Target variable is Price. We gone predict flight prices using Various Regression Algorithms.
#     Some feature with date and time related columns are mention with object datatype. We gone convert them into datetime datatype format along with going to perform some feature engineering over them to create few new columns of our interest.

# %% [markdown]
# Data Integrity Check
#
#     Dataset can contain whitespaces, missing value, duplicates entries, let investigate integrity of data before proceeding for further analysis.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isin([' ','?','-','null','NA']).sum().any()
# Out:
# False

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.isnull(), cmap= 'cool_r')
plt.show()

# %% [markdown]
# .Dataset doesnot contain duplicate data or any missing value.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# 1.Conversion of Duration column hr & Minutes format to Minutes

# %%
df['Duration'] = df['Duration'].map(lambda x : x.replace('05m','5m'))

# %%
# Conversion of Duration column from hr & Minutes format to Minutes
df['Duration'] = df['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)

# convert this column into a numeric datatypes
df['Duration']= pd.to_numeric(df['Duration'])

# %% [markdown]
# 2.Create new column for day & date

# %%
df['Day']= df['Date'].map(lambda x :x[:3])

# %%
df['Date']= df['Date'].map(lambda x :x[4:])

# %%
Categorical = ['Airline','Class','Day','Stops','Aeroplane']

# %%
pd.set_option('display.max_rows',None)
for i in Categorical :
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Airline
# Vistara Premium Economy    619
# Air India                  435
# Vistara                    421
# Air India Business         396
# Vistara Business           370
# Go First                   319
# IndiGo                     270
# SpiceJet                   125
# Name: Airline, dtype: int64
# ====================================================================================================
# Class
# Ecomony Class      1570
level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_63b27_row0_col0" class="data row0 col0" >2955</td>
#       <td id="T_63b27_row0_col1" class="data row0 col1" >2955</td>
#       <td id="T_63b27_row0_col2" class="data row0 col2" >2955</td>
#       <td id="T_63b27_row0_col3" class="data row0 col3" >2955</td>
#       <td id="T_63b27_row0_col4" class="data row0 col4" >2955</td>
#       <td id="T_63b27_row0_col5" class="data row0 col5" >2955</td>
#       <td id="T_63b27_row0_col6" class="data row0 col6" >2955</td>
#       <td id="T_63b27_row0_col7" class="data row0 col7" >2955</td>
#       <td id="T_63b27_row0_col8" class="data row0 col8" >2955</td>
#       <td id="T_63b27_row0_col9" class="data row0 col9" >2955</td>
#     </tr>
#     <tr>
#       <th id="T_63b27_level0_row1" class="row_heading level0 row1" >unique</th>
#       <td id="T_63b27_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_63b27_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_63b27_row1_col2" class="data row1 col2" >260</td>
#       <td id="T_63b27_row1_col3" class="data row1 col3" >13</td>
#       <td id="T_63b27_row1_col4" class="data row1 col4" >120</td>
#       <td id="T_63b27_row1_col5" class="data row1 col5" >150</td>
#       <td id="T_63b27_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_63b27_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_63b27_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_63b27_row1_col9" class="data row1 col9" >7</td>
#     </tr>
#     <tr>
#       <th id="T_63b27_level0_row2" class="row_heading level0 row2" >top</th>
#       <td id="T_63b27_row2_col0" class="data row2 col0" >Vistara Premium Economy</td>
#       <td id="T_63b27_row2_col1" class="data row2 col1" >Ecomony Class</td>
#       <td id="T_63b27_row2_col2" class="data row2 col2" >UK-981</td>
#       <td id="T_63b27_row2_col3" class="data row2 col3" > 2 Feb 2022</td>
#       <td id="T_63b27_row2_col4" class="data row2 col4" >07:30:00</td>
#       <td id="T_63b27_row2_col5" class="data row2 col5" >23:00:00</td>
#       <td id="T_63b27_row2_col6" class="data row2 col6" >New Delhi</td>
#       <td id="T_63b27_row2_col7" class="data row2 col7" >Mumbai</td>
#       <td id="T_63b27_row2_col8" class="data row2 col8" >1 Stop</td>
#       <td id="T_63b27_row2_col9" class="data row2 col9" >Wed</td>
#     </tr>
#     <tr>
#       <th id="T_63b27_level0_row3" class="row_heading level0 row3" >freq</th>
#       <td id="T_63b27_row3_col0" class="data row3 col0" >619</td>
#       <td id="T_63b27_row3_col1" class="data row3 col1" >1570</td>
#       <td id="T_63b27_row3_col2" class="data row3 col2" >39</td>
#       <td id="T_63b27_row3_col3" class="data row3 col3" >274</td>
#       <td id="T_63b27_row3_col4" class="data row3 col4" >125</td>
#       <td id="T_63b27_row3_col5" class="data row3 col5" >156</td>
#       <td id="T_63b27_row3_col6" class="data row3 col6" >2955</td>
#       <td id="T_63b27_row3_col7" class="data row3 col7" >2955</td>
#       <td id="T_63b27_row3_col8" class="data row3 col8" >2007</td>
#       <td id="T_63b27_row3_col9" class="data row3 col9" >505</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # EDA

# %% [markdown]
# Exploring Airline Types

# %%
# Pie & count plot of Airline types
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set1')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Airline'].value_counts().plot.pie(autopct='%2.1f%%',
                                          textprops ={ 'fontsize':13,'fontweight' :'bold'}, ax=ax[0],shadow=True)
ax[0].set_title('FlightWise Distribution of Airlines', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Airline',data=df,ax=ax[1])
ax[1].set_title('Airline Vs No of Flights',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Airline",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Flights",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=12,rotation= 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
#
#     We can see maximum number of flights run by Vistara Premium Economy while minimum Flights run by Spicejet.
#     Around 25% of flights of Business Class.

# %%
# Counting class type
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set1_r')
f,ax=plt.subplots(1,2,figsize=(14,6))
df['Class'].value_counts().plot.pie(autopct='%2.1f%%',
                                          textprops ={ 'fontsize':13,'fontweight' :'bold'}, ax=ax[0],shadow=True)
ax[0].set_title('Class-Wise Distribution of Flights', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Class',data=df,ax=ax[1])
ax[1].set_title('Class Vs No of Flights',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Class",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Flights",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=12,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
#
#     53.1% flights are of Ecomony class, as they are low cost of flight & most of people prefer it.
#     There are more business class flights than Premuim Ecomony flights. It strange because Business class is costlier than Premuim Ecomony class.

# %%
# Counting No of stops
plt.rcParams["figure.autolayout"] = True
sns.set_palette('hsv')
f,ax=plt.subplots(1,2,figsize=(14,6))
df['Stops'].value_counts().plot.pie(autopct='%2.1f%%',
                                          textprops ={ 'fontsize':14,'fontweight' :'bold'}, ax=ax[0],shadow=True)
ax[0].set_title('Stops-Wise Distribution of Flights', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Stops',data=df,ax=ax[1])
ax[1].set_title('Stops Vs No of Flights',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Stops",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Flights",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=12,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
#
#     67.9% flights take single stop in there way from New Dehli to Mumbai.It is also possible that these flights may have high flight duration compare to Non-stop Flight
#     30% of flights do not have any stop in there route.

# %%
# Counting No of days
plt.rcParams["figure.autolayout"] = True
sns.set_palette('hsv')
f,ax=plt.subplots(1,2,figsize=(14,6))
df['Day'].value_counts().plot.pie(autopct='%2.1f%%',
                                          textprops ={ 'fontsize':14,'fontweight' :'bold'}, ax=ax[0],shadow=True)
ax[0].set_title('Day-Wise Distribution of Flights', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Day',data=df,ax=ax[1])
ax[1].set_title('Day Vs No of Flights',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Day",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Flights",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=12,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# On Wednesday Maximum flights run while on saturday minimum flights run

# %% [markdown]
# It will be interesting to investigate variation of fare as per different week days.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('gnuplot')
plt.figure(figsize =(14,7))
sns.barplot(x=df['Day'],y=df['Price'],hue=df['Class'])
plt.title("Day Vs Price",fontsize=20,fontweight ='bold')
plt.xlabel('Day',fontsize = 20,fontweight ='bold')
plt.ylabel('Avg. Price of Flights',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
#
#     Maximum Avg. Fare for Business Flights is on Wedsday while minimum Avg. Fare for Business flights on Thursday.
#     For Ecomony Flights & Premium Ecomony Flights: Minimum Avg. Fare on Friday.
#     For Ecomony Flights & Premium Ecomony Flights: Maximum Avg. Fare on Monday.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('gnuplot')
plt.figure(figsize =(14,7))
sns.barplot(x=df['Class'],y=df['Duration'],hue=df['Stops'])
plt.title("Class Vs Duration",fontsize=20,fontweight ='bold')
plt.xlabel('Class',fontsize = 20,fontweight ='bold')
plt.ylabel('Avg. Duration of Flights',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Observation:
#
#     -As Number of Stops increase the duration of flights increases.
#     -As per Class of flight Maximum Avg. Duration of flight is for Business class.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('mako')
plt.figure(figsize =(14,7))
sns.countplot(x=df['Date'])
plt.title("Date-wise Flight Distribution",fontsize=20,fontweight ='bold')
plt.xlabel('Date',fontsize = 20,fontweight ='bold')
plt.ylabel('No of Flights',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# We can see those Maximum flights schedule on 2 Feb 2022 & Minimum flights schedule on 24 Jan 2022.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('mako')
plt.figure(figsize =(12,8))
sns.swarmplot(y=df['Price'],x=df['Stops'], hue= df['Day'])
plt.title("Price VS Stops",fontsize=20,fontweight ='bold')
plt.xlabel('No. of Stop',fontsize = 20,fontweight ='bold')
plt.ylabel('Price',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('hsv')
plt.figure(figsize =(8,5))
sns.swarmplot(y=df['Duration'],x=df['Stops'], hue =df['Class'])
plt.title("Stops VS Duration",fontsize=20,fontweight ='bold')
plt.xlabel('No of Stops',fontsize = 20,fontweight ='bold')
plt.ylabel('Duration ',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow_r')
plt.figure(figsize =(10,8))
sns.swarmplot(x=df['Airline'],y=df['Duration'], hue =df['Class'])
plt.title("Airline VS Duration",fontsize=20,fontweight ='bold')
plt.xlabel('Airline',fontsize = 20,fontweight ='bold')
plt.ylabel('Duration',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # *Feature Engineering*

# %% [markdown]
# 1. Encoding Categorical Data

# %%
# Dropping Unnecessary columns
df.drop(columns=['Departure_Time','Arrival_Time','Source','Destination'], inplace= True)

# %%
# lets sort columns by their datatype
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Duration', 'Price'], object: ['Airline', 'Class', 'Aeroplane', 'Date', 'Stops', 'Day']}

# %%
Categorical = ['Airline', 'Class', 'Aeroplane', 'Date', 'Stops', 'Day']
Numerical = ['Duration', 'Price']

# %%
df['Aeroplane']= df['Aeroplane'].map(lambda x: str(x).replace('-',''))
df['Aeroplane']= df['Aeroplane'].map(lambda x: str(x).replace('/',''))

# %%
# Using Label encoder for transforming Categorical data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical:
    df[i] =le.fit_transform(df[i])
df.head()
# Out:
#    Airline  Class  Aeroplane  Date  Stops  Duration  Price  Day
# 0        2      1        130     2      2       130   5954    3
# 1        2      1        134     2      2       130   5954    3
# 2        2      1        122     2      2       135   5954    3
# 3        2      1        135     2      2       135   5954    3
# 4        2      1        131     2      2       135   5954    3

# %% [markdown]
# We have sucessfully converted Categorical variable in numerical variable using label encoder

# %% [markdown]
# # 2. Outliers Detection & Removal

# %%
plt.figure(figsize=(15,4), facecolor ='white')
plt_num = 1
for i in Numerical:
    if plt_num <= 2:
        ax = plt.subplot(1,2,plt_num)
        sns.boxplot(df[i], palette='gnuplot')
        plt.xlabel(i, fontsize= 16)
    plt_num += 1
plt.show()

# %% [markdown]
# From Boxplot we can see presense of outliers.
#
# Since Data is realstic and data is error-free, we will Proceed for building ML model without removing outliers. Since Outliers detected are with realstic value.

# %% [markdown]
# # 3. Correlation

# %%
df.corr()
# Out:
#             Airline     Class  Aeroplane      Date     Stops  Duration  \
# Airline    1.000000  0.438941   0.789746  0.017338  0.037179  0.045681
# Class      0.438941  1.000000   0.257569  0.011258 -0.061700  0.040081
# Aeroplane  0.789746  0.257569   1.000000  0.020461  0.196011 -0.028729
# Date       0.017338  0.011258   0.020461  1.000000  0.006696  0.011823
# Stops      0.037179 -0.061700   0.196011  0.006696  1.000000 -0.606977
# Duration   0.045681  0.040081  -0.028729  0.011823 -0.606977  1.000000
# Price      0.009741 -0.704708   0.043954 -0.055609 -0.172458  0.238488
# Day       -0.006195 -0.008282  -0.006735 -0.620776 -0.009300 -0.009331
#
#               Price       Day
# Airline    0.009741 -0.006195
# Class     -0.704708 -0.008282
# Aeroplane  0.043954 -0.006735
# Date      -0.055609 -0.620776
# Stops     -0.172458 -0.009300
# Duration   0.238488 -0.009331
# Price      1.000000  0.055829
# Day        0.055829  1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),linecolor='black', vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap='gist_stern')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (12,6))
df.corr()['Price'].drop(['Price']).sort_values(ascending=False).plot(kind='bar',cmap = 'spring')
plt.xlabel('Features',fontsize=15,fontweight='bold')
plt.ylabel('Price (Rs.)',fontsize=15,fontweight='bold')
plt.title('Correlation of features with Target Variable Price (Rs.)',fontsize = 20,fontweight='bold')
plt.show()

# %% [markdown]
# Observation:
#
#     We can observe that class is highly correlated with target variable Price.
#     Most of features are moderately & poorly correlated with each other.

# %% [markdown]
# # 4. Skewness detection

# %%
df.skew()
# Out:
# Airline     -0.104472
# Class        0.062718
# Aeroplane   -0.138638
# Date         0.003528
# Stops        0.820233
# Duration     0.777539
# Price        1.273832
# Day         -0.152787
# dtype: float64

# %% [markdown]
#     We can see Price, Stops & Duration are skewed features.
#     We cannot transform Price features as it is target variable while stops is categorical variable so concept of skewness doesnot applicable to it.

# %% [markdown]
# # Standard Scaling

# %%
# Splitting data in target and dependent feature
X = df.drop(['Price'], axis=1)
Y = df['Price']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=99, test_size=0.33)
print('Training Feature Matrix Size:', X_train.shape)
print('Training Target Vector Size :', Y_train.shape)
print('Test Feature Matrix Size:', X_test.shape)
print('Test Target Vector Size:', Y_test.shape)
# Out:
# Training Feature Matrix Size: (1979, 7)
# Training Target Vector Size : (1979,)
# Test Feature Matrix Size: (976, 7)
# Test Target Vector Size: (976,)

# %% [markdown]
# # Finding best Random state

# %%
maxR2_score=0
maxRS=0
for i in range(50,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.7332282158142227 on Random_state 70

# %% [markdown]
# # Linear Regression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
lin_reg= LinearRegression()
lin_reg.fit(X_train, Y_train)
y_pred = lin_reg.predict(X_test)
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error :
# Mean absolute error : 5625.518848733739
# Mean squared error : 47501598.014805496
# Root Mean squared error : 6892.140307248938
#  R2 Score :
# 73.32282158142228

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : -16.392609635258427

# %% [markdown]
# # Random Forest Regressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
rfc = RandomForestRegressor()
rfc.fit(X_train, Y_train)
y_pred = rfc.predict(X_test)
print('\033[1m'+ 'Error of Random Forest Regressor:'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+'R2 Score of Random Forest Regressor :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error of Random Forest Regressor:
# Mean absolute error : 546.8830122950819
# Mean squared error : 1941774.8315625
# Root Mean squared error : 1393.4758094644126
# R2 Score of Random Forest Regressor :
# 98.90948776893461

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(rfc, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',rfc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.799371622400131

# %% [markdown]
# # Decision Tree Regressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
dtc = DecisionTreeRegressor()
dtc.fit(X_train, Y_train)
y_pred = dtc.predict(X_test)
print('\033[1m'+ 'Error of Decision Tree Regressor:'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+'R2 Score of Decision Tree Regressor :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error of Decision Tree Regressor:
# Mean absolute error : 418.577868852459
# Mean squared error : 2582856.7131147543
# Root Mean squared error : 1607.12685034964
# R2 Score of Decision Tree Regressor :
# 98.54945239223515

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(dtc, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',dtc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.6629472642186334

# %% [markdown]
# # Extra Trees Regressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
etc = ExtraTreesRegressor()
dtc.fit(X_train, Y_train)
y_pred = dtc.predict(X_test)
print('\033[1m'+ 'Error of Extra Tree Regressor:'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+'R2 Score of Extra Tree Regressor :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error of Extra Tree Regressor:
# Mean absolute error : 436.8125
# Mean squared error : 2769525.7961065574
# Root Mean squared error : 1664.189230858846
# R2 Score of Extra Tree Regressor :
# 98.4446179310734

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(etc, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',etc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : 0.6725097048280263

# %% [markdown]
# # XGB Regressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
xgb = XGBRegressor()
xgb.fit(X_train, Y_train)
y_pred = xgb.predict(X_test)
print('\033[1m'+ 'Error of XGB Regressor:'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+'R2 Score of XGB Regressor :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error of XGB Regressor:
# Mean absolute error : 595.8423259297356
# Mean squared error : 1756957.5071066087
# Root Mean squared error : 1325.502737494951
# R2 Score of XGB Regressor :
# 99.0132822715494

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(xgb, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',xgb,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...) :
#
# Mean CV Score : 0.7582055095451483

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We can see that XGB Regressor gives maximum R2 score of 99.013 and maximum cross validation score. Among all model we will select XGB Regressor as final model and we will perform hyper parameter tuning over this model to enhance its R2 Score.

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=70, test_size=0.33)

# %%
parameter = {'n_estimators':[400,500],'gamma':np.arange(0,0.2,0.1),
              'booster' : ['gbtree','dart','gblinear'], 'max_depth':[6,8],
              'eta' : [0.01, 0.1] }

# %%
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =10)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 1/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.985 total time=   0.7s
# [CV 2/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 2/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.983 total time=   0.7s
# [CV 3/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 3/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.986 total time=   0.7s
# [CV 4/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 4/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.974 total time=   0.7s
# [CV 5/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 5/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.984 total time=   0.7s
# [CV 1/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 1/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.988 total time=   0.9s
# [CV 2/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 2/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.986 total time=   0.9s
# [CV 3/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 3/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.988 total time=   0.9s
# [CV 4/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 4/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.979 total time=   0.9s
# [CV 5/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 5/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.988 total time=   1.0s
# [CV 1/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 1/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.987 total time=   0.9s
# [CV 2/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 2/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.983 total time=   0.9s
# [CV 3/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 3/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.989 total time=   0.9s
# [CV 4/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 4/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.977 total time=   0.9s
# [CV 5/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 5/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.989 total time=   0.9s
# [CV 1/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 1/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.990 total time=   1.2s
# [CV 2/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 2/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.986 total time=   1.1s
# [CV 3/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 3/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.991 total time=   1.1s
# [CV 4/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 4/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.980 total time=   1.1s
# [CV 5/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 5/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.992 total time=   1.1s
# [CV 1/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 1/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.985 total time=   0.7s
# [CV 2/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 2/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.983 total time=   0.7s
# [CV 3/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 3/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.986 total time=   0.7s
# [CV 4/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 4/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.974 total time=   0.7s
# [CV 5/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 5/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.984 total time=   0.7s
# [CV 1/5; 6/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500
# [CV 1/5; 6/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500;, score=0.988 total time=   0.9s
# [CV 2/5; 6/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500
# [CV 2/5; 6/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500;, score=0.986 total time=   0.9s
# [CV 3/5; 6/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500
# [CV 3/5; 6/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500;, score=0.988 total time=   0.9s
# [CV 4/5; 6/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500
# [CV 4/5; 6/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500;, score=0.979 total time=   0.9s
# [CV 5/5; 6/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500
# [CV 5/5; 6/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=500;, score=0.988 total time=   0.9s
# [CV 1/5; 7/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400
# [CV 1/5; 7/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400;, score=0.987 total time=   0.9s
# [CV 2/5; 7/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400
# [CV 2/5; 7/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400;, score=0.983 total time=   0.9s
# [CV 3/5; 7/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400
# [CV 3/5; 7/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400;, score=0.989 total time=   0.9s
# [CV 4/5; 7/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400
# [CV 4/5; 7/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400;, score=0.977 total time=   0.9s
# [CV 5/5; 7/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400
# [CV 5/5; 7/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=400;, score=0.989 total time=   0.9s
# [CV 1/5; 8/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500
# [CV 1/5; 8/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500;, score=0.990 total time=   1.1s
# [CV 2/5; 8/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500
# [CV 2/5; 8/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500;, score=0.986 total time=   1.1s
# [CV 3/5; 8/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500
# [CV 3/5; 8/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500;, score=0.991 total time=   1.2s
# [CV 4/5; 8/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500
# [CV 4/5; 8/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500;, score=0.980 total time=   1.1s
# [CV 5/5; 8/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500
# [CV 5/5; 8/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=8, n_estimators=500;, score=0.992 total time=   1.2s
# [CV 1/5; 9/48] START booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400
# [CV 1/5; 9/48] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.993 total time=   0.8s
# [CV 2/5; 9/48] START booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400
# [CV 2/5; 9/48] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0.986 total time=   0.7s
# [CV 3/5; 9/48] START booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400
# [CV 3/5; 9/48] END booster=gbtree, eta=0.1, gamma=0.0, max_depth=6, n_estimators=400;, score=0
WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.696 total time=   0.3s
# [CV 2/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [12:32:15] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.664 total time=   0.3s
# [CV 3/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [12:32:15] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.664 total time=   0.3s
# [CV 4/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [12:32:15] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.694 total time=   0.3s
# [CV 5/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [12:32:16] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.705 total time=   0.3s
# [CV 1/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [12:32:16] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.696 total time=   0.4s
# [CV 2/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [12:32:17] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.664 total time=   0.4s
# [CV 3/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [12:32:17] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.664 total time=   0.4s
# [CV 4/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [12:32:18] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.694 total time=   0.4s
# [CV 5/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [12:32:18] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.705 total time=   0.4s
# [CV 1/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [12:32:19] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.696 total time=   0.3s
# [CV 2/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [12:32:19] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.664 total time=   0.3s
# [CV 3/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [12:32:19] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.664 total time=   0.3s
# [CV 4/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [12:32:20] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.694 total time=   0.3s
# [CV 5/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [12:32:20] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.705 total time=   0.3s
# [CV 1/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [12:32:21] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.696 total time=   0.4s
# [CV 2/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [12:32:21] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.664 total time=   0.4s
# [CV 3/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [12:32:22] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.664 total time=   0.4s
# [CV 4/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [12:32:22] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.694 total time=   0.4s
# [CV 5/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [12:32:23] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.705 total time=   0.4s
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_to_o...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None, ...),
#              param_grid={'booster': ['gbtree', 'dart', 'gblinear'],
#                          'eta': [0.01, 0.1], 'gamma': array([0. , 0.1]),
#                          'max_depth': [6, 8], 'n_estimators': [400, 500]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'booster': 'dart',
#  'eta': 0.1,
#  'gamma': 0.1,
#  'max_depth': 6,
#  'n_estimators': 400}

# %% [markdown]
# # Final Model

# %%
Final_mod=XGBRegressor(booster='gbtree', max_depth=6, eta=0.1,
                                gamma=0.1, n_estimators=400)
Final_mod.fit(X_train,Y_train)
pred=Final_mod.predict(X_test)
print('R2_Score:',r2_score(Y_test,pred)*100)
print('mean_squared_error:',mean_squared_error(Y_test,pred))
print('mean_absolute_error:',mean_absolute_error(Y_test,pred))
print("RMSE value:",np.sqrt(mean_squared_error(Y_test, pred)))
# Out:
# R2_Score: 99.10082852169405
# mean_squared_error: 1601071.9514146028
# mean_absolute_error: 516.4768021380315
# RMSE value: 1265.3347191216255

# %% [markdown]
# # Saving Model

# %%
# Saving the model using .pkl
import joblib
joblib.dump(Final_mod,"Flight_Price_Prediction.pkl")
# Out:
# ['Flight_Price_Prediction.pkl']

# %% [markdown]
# # Predictions Using Final Model

# %%
# Loading the saved model
model = joblib.load("Flight_Price_Prediction.pkl")

# Prediction
prediction = model.predict(X_test)
prediction
# Out:
# array([ 6014.969 , 41552.758 , 14805.451 , 11701.863 , 10004.448 ,
#         5959.1714,  9282.237 ,  7180.5845,  6788.4233, 40908.016 ,
#        30130.402 , 10549.416 , 11253.479 ,  5941.127 , 35509.19  ,
#         6909.0615, 11717.267 ,  7279.373 ,  5360.979 , 41068.934 ,
#         6012.3174,  5956.4224,  3902.5193,  6125.695 ,  2817.9634,
#        30585.45  ,  7554.0396, 14018.352 ,  3264.9182, 10043.147 ,
#        10309.977 ,  7702.6973, 11534.227 , 11768.313 , 11212.3   ,
#        45955.824 ,  5946.07  , 14071.319 , 36408.402 , 10963.154 ,
#         3110.0227, 40821.4   ,  5466.0376,  5852.516 , 37383.39  ,
